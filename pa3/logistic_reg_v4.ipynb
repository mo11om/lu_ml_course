# %% [markdown]
# ## In-class hands-on activity: Logistic Regression
#
# ### Heart Failure Prediction
# Original dataset from <https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction/data>
#
# In-class exercise: Fitting logistic regression and compute performance.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing

# %matplotlib inline

pd.set_option('display.max_column', 500)
pd.set_option('display.max_rows', 5000)
random.seed(1001)
np.random.seed(1001)

# %% [markdown]
# ### Simulated Data for two variable case

# %%
# Class 1 centered at (1, 1), class 0 centered at (-1, -1)
#    Std dev for two features are 1.1, 0.8

# number of class 1 data points
n1 = 20
# number of class 0 data points
n0 = 20

mean1 = np.array([1, 1])
cov1 = np.array([[2.5, 0.3],
                [0.3, 2.2]])

mean0 = np.array([-1, -1])
cov0 = np.array([[2.5, 0.3],
                [0.3, 2.2]])


train1 = np.random.multivariate_normal(mean1, cov1, n1)
train0 = np.random.multivariate_normal(mean0, cov0, n0)

train = np.vstack((train1, train0))
df_train = pd.DataFrame.from_records(train)
df_train.columns = ("x1", "x2")
df_train['label'] = 1
df_train.iloc[n1:, 2] = 0

# %%
sns.scatterplot(data=df_train, x="x1", y="x2", hue="label")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
clf0 = linear_model.LogisticRegression(C=1000)
clf0.fit(train,df_train.label.values)
print(f"Coefficient: {clf0.coef_}")
print(f" Intercept: {clf0.intercept_}")

clf0.decision_function
# Out:
# Coefficient: [[1.21182284 1.02067065]]
#  Intercept: [0.63376563]
# <bound method LinearClassifierMixin.decision_function of LogisticRegression(C=1000)>

# %%
xx, yy = np.mgrid[-5:5:.01, -5:5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
prob0 = clf0.predict_proba(grid)[:, 1]
probs = prob0.reshape(xx.shape)

# %%
f, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)

# %%
idx = np.abs(prob0 - 0.5) < 0.01
subgrid = grid[idx]

# %%
# sns.scatterplot(data=df_train, x="x1", y="x2", hue="label")
# sns.lineplot(x = subgrid[:,0], y = subgrid[:,1])
plt.plot(subgrid[:,0], subgrid[:,1])
plt.scatter(train1[:,0], train1[:,1], color = "black")
plt.scatter(train0[:,0], train0[:,1], color = "red")

# %%
# sns.scatterplot(data=df_train, x="x1", y="x2", hue="label")
# sns.lineplot?

# %% [markdown]
# ### 資料說明 (From the original data provider)
#
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Four out of 5CVD deaths are due to heart attacks and strokes, and one-third of these deaths occur prematurely in people under 70 years of age. Heart failure is a common event caused by CVDs and this dataset contains 11 features that can be used to predict a possible heart disease.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help.
#
# ### Attribute Information
# * Age: age of the patient [years]
# * Sex: sex of the patient [M: Male, F: Female]
# * ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# * RestingBP: resting blood pressure [mm Hg]
# * Cholesterol: serum cholesterol [mm/dl]
# * FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# * RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# * MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# * ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# * Oldpeak: oldpeak = ST [Numeric value measured in depression]
# * ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# * HeartDisease: output class [1: heart disease, 0: Normal]

# %%
# Start with data loading and showing sample data
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# make sure the data types are reasonable
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.HeartDisease.value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
cat_cols = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
df_wc=pd.get_dummies(df,columns=cat_cols, drop_first=False)
df_wc.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0  False   True              False               True              False
# 1   True  False              False              False               True
# 2  False   True              False               True              False
# 3   True  False               True              False              False
# 4  False   True              False              False               True
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0             False           False               True          False
# 1             False           False               True          False
# 2             False           False              False           True
# 3             False           False               True          False
# 4             False           False               True          False
#
#    ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 0              True             False          False          False
# 1              True             False          False           True
# 2              True             False          False          False
# 3             False              True          False           True
# 4              True             False          False          False
#
#    ST_Slope_Up
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True

# %%
# split training and test

mask1 = np.random.rand(len(df_wc)) < 0.9
df_wc_train = df_wc[mask1].copy()
df_wc_test = df_wc[~mask1].copy()

target = 'HeartDisease'
featnames = df_wc.columns.to_list()
featnames.remove(target)

print("Features to be include in the model", featnames)
# Out:
# Features to be include in the model ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat', 'ST_Slope_Up']

# %%
X_train = df_wc_train[featnames].values
y_train = df_wc_train[target].values

X_test = df_wc_test[featnames].values
y_test = df_wc_test[target].values

mm_scaler=preprocessing.MinMaxScaler()
X_train=mm_scaler.fit_transform(X_train)
X_test=mm_scaler.transform(X_test)

# %% [markdown]
# ### TODO
#
# * What will happen to binary features and numerical features after applying MinMaxScalar()?
# * Verify that X_train and X_test has been properly scaled.

# %%
# TODO

# --- remove below ---
# 1. Since the default range for MinMaxScalar is [0, 1], the binary features will not be influenced by this operation. 
#    On the other hand, numerical features will in general be affected by this operation.

# 2. Use describe() to verify this operation. 
print(f"The shape of X_train is {X_train.shape}")
xmin1 = X_train.min(axis=0)
xmax1 = X_train.max(axis=0)
xmean1 = X_train.mean(axis=0)

xmmm1 = np.vstack((xmin1, xmax1, xmean1))
print("The min, max, and mean for X_train")
print(xmmm1.T)
                  

print(f"The shape of X_test is {X_test.shape}")
xmin2 = X_test.min(axis=0)
xmax2 = X_test.max(axis=0)
xmean2 = X_test.mean(axis=0)

xmmm2 = np.vstack((xmin2, xmax2, xmean2))
print("The min, max, and mean for X_test")
print(xmmm2.T)

# --- remove above ---
# Out:
# The shape of X_train is (829, 20)
# The min, max, and mean for X_train
# [[0.         1.         0.51975579]
#  [0.         1.         0.66025935]
#  [0.         1.         0.32840022]
#  [0.         1.         0.23642943]
#  [0.         1.         0.54063949]
#  [0.         1.         0.42465209]
#  [0.         1.         0.20506634]
#  [0.         1.         0.79493366]
#  [0.         1.         0.5331725 ]
#  [0.         1.         0.18576598]
#  [0.         1.         0.22557298]
#  [0.         1.         0.05548854]
#  [0.         1.         0.19903498]
#  [0.         1.         0.59831122]
#  [0.         1.         0.2026538 ]
#  [0.         1.         0.59589867]
#  [0.         1.         0.40410133]
#  [0.         1.         0.06513872]
#  [0.         1.         0.49819059]
#  [0.         1.         0.43667069]]
# The shape of X_test is (89, 20)
# The min, max, and mean for X_test
# [[0.14285714 0.97959184 0.5287778 ]
#  [0.47       1.         0.67803371]
#  [0.         0.67827529 0.34164384]
#  [0.         1.         0.20224719]
#  [0.19014085 0.90140845 0.54344042]
#  [0.18292683 1.07317073 0.43121403]
#  [0.         1.         0.25842697]
#  [0.         1.         0.74157303]
#  [0.         1.         0.60674157]
#  [0.         1.         0.21348315]
#  [0.         1.         0.17977528]
#  [0.         0.         0.        ]
#  [0.         1.         0.25842697]
#  [0.         1.         0.62921348]
#  [0.         1.         0.11235955]
#  [0.         1.         0.59550562]
#  [0.         1.         0.40449438]
#  [0.         1.         0.1011236 ]
#  [0.         1.         0.52808989]
#  [0.         1.         0.37078652]]

# %% [markdown]
# ### --- remove below ---
# ### Discussion for this TODO
#
# We can see that for X_test, the minimal and maximum values for each features may not be exactly 0 and 1. This is reasonable because the unseen data in the test set may have a slightly different data range. However, given that we have split training and test randomly, and the dataset size is large enough, we should see the data range in the test set lie closely to 0 and 1.
#
# ### --- remove above ---

# %% [markdown]
# ### Fitting Logistic Regression
#
# Use linear_model.LogisticRegressionCV() to fit a logistic regression model to the training data. Use metrics.classification_report() to compute prediction performance. Answer the following questions.
#
# 1. List first five coefficients and their feature names.
# 2. Interpret the meanings of these feature coefficients.
# 3. Show the regularization coefficient selected by the CV routine.
# 4. Apply the model to predict the test set. What is the accuracy, precision, and recall?

# %%
# TODO
# --- remove below ---
clf=linear_model.LogisticRegressionCV()
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)


print("First five features and coefficients")
for coef, fname in zip(clf.coef_.flatten(), featnames[0:5]):
    print(f"{fname:12s}: {coef:.4f}")

print("---")
print(f"The regularization coefficient is {clf.C_[0]:.4f}")

print("---")
print(metrics.classification_report(y_test, y_pred, digits=4))

# --- remove above ---
# Out:
# First five features and coefficients
# Age         : 0.2195
# RestingBP   : 0.0105
# Cholesterol : -0.3501
# FastingBS   : 0.5774
# MaxHR       : -0.2445
# ---
# The regularization coefficient is 0.0464
# ---
#               precision    recall  f1-score   support
#
#            0     0.8611    0.7750    0.8158        40
#            1     0.8302    0.8980    0.8627        49
#
#     accuracy                         0.8427        89
#    macro avg     0.8456    0.8365    0.8393        89
# weighted avg     0.8441    0.8427    0.8416        89

# %% [markdown]
# accuracy = 0.8286
#
# for the positive cases, precision = 0.8136, recall = 0.8727, F1 = 0.8421.

# %% [markdown]
# ### Compute Accuracy, Precision, Recall, and F1 from scratch.
# Use numpy to do the work. You should not use existing library such as metrics.classification_report().

# %%
# TODO

# --- remove below ---
acc = np.sum(y_test == y_pred) / y_test.shape[0]
print(f"Accuracy = {acc:.4f}")

# recall
npositive = np.sum(y_test)
recall = np.sum(y_test * y_pred) / npositive
print(f"Recall = {recall:.4f}")

# precision
npredp = np.sum(y_pred)
precision = np.sum(y_test * y_pred) / npredp
print(f"Precision = {precision:.4f}")

# F1
f1 = 2 * precision * recall / (precision + recall)
print(f"F1 score = {f1:.4f}")

# --- remove above ---
# Out:
# Accuracy = 0.8427
# Recall = 0.8980
# Precision = 0.8302
# F1 score = 0.8627

# %% [markdown]
# ### Explore the prediction results
#
# Create a new data frame that contain the following columns (in this order):
# * Pred: the predicted value for test examples
# * Predp: the predicted probability for test examples.
# * HearDisease: the ground truth for the test examples.
# * All the remaining features.
#
# Go through the prediction errors. Think about the following questions.
# 1. Why the model made wrong predictions for certain examples?
# 2. How can we improve the performance?
#
# ### --- remove below ---
# 1. For ID 19, the case is young so the model predicted that the case is negative. Case 183 and 188; need professional knowledge to analyze.
# 2. Two directions in general. (1) Lack of information --> Add more features (2) the model cannot capture the complex relations --> More advanced models and a larger training set.
#
# ### --- remove above ---

# %%
# TODO

# --- remove below ---
y_predprob = clf.predict_proba(X_test)
df_wc_test['Pred'] = y_pred
df_wc_test['Predp'] = y_predprob[:,1]

origcol = list(df_wc_test.columns)

headcol = ['Pred', 'Predp', 'HeartDisease']
for aitem in headcol:
    origcol.remove(aitem)
newcol = headcol + origcol

df_wc_test2 = df_wc_test[newcol]

df_wc_test2
# --- remove above ---
# Out:
#      Pred     Predp  HeartDisease  Age  RestingBP  Cholesterol  FastingBS  \
# 4       0  0.177231             0   54        150          195          0
# 6       0  0.059291             0   45        130          237          0
# 19      0  0.471419             1   36        120          267          0
# 27      0  0.144474             0   52        120          284          0
# 33      1  0.792730             1   41        130          172          0
# 36      1  0.948132             1   65        140          306          1
# 42      0  0.127007             0   35        150          264          0
# 47      0  0.137457             0   50        140          216          0
# 53      0  0.059957             0   41        130          245          0
# 71      0  0.141469             0   44        130          215          0
# 78      0  0.332012             0   52        140          100          0
# 86      1  0.947975             1   65        170          263          1
# 92      0  0.064177             0   52        120          210          0
# 117     1  0.881151             1   59        130          338          1
# 128     0  0.109949             0   54        120          230          1
# 168     0  0.391453             0   58        135          222          0
# 171     0  0.149908             0   40        140          235          0
# 181     0  0.141507             0   51        130          224          0
# 183     1  0.907768             0   46        110          238          0
# 188     1  0.786164             0   50        120          328          0
# 198     1  0.901898             1   53        120          246          0
# 202     0  0.167715             0   42        160          147          0
# 206     0  0.125304             0   35        120          308          0
# 209     1  0.767324             1   54        125          216          0
# 232     0  0.060226             0   38        120          275          0
# 241     1  0.905816             1   54        200          198          0
# 247     1  0.896743             1   48        122          275          1
# 260     0  0.294407             0   46        140          275          0
# 274     0  0.056655             0   45        180          295          0
# 285     0  0.080403             0   51        110          190          0
# 286     0  0.383537             0   59        140          169          0
# 302     1  0.561617             1   53        125            0          1
# 332     0  0.164687             0   38        100            0          0
# 345     1  0.802758             1   69        135            0          0
# 365     1  0.818713             1   64        200            0          0
# 373     1  0.918143             1   59        135            0          0
# 374     1  0.847650             1   61        125            0          0
# 381     1  0.913257             1   50        115            0          0
# 408     1  0.880470             1   59        110            0          1
# 425     1  0.650480             1   60        160          267          1
# 428     1  0.917403             1   62        110            0          0
# 441     1  0.892758             1   69        130            0          1
# 470     1  0.797830             1   53        126            0          0
# 476     1  0.518701             0   51        132          218          1
# 490     1  0.788897             1   72        120          214          0
# 491     1  0.884915             1   75        170          203          1
# 500     1  0.837152             1   65        136          248          0
# 512     0  0.175381             0   35        123          161          0
# 523     1  0.910557             1   59        124          160          0
# 526     1  0.910358             1   65        144          312          0
# 528     1  0.773454             1   49        131          142          0
# 541     0  0.439267             1   76        104          113          0
# 569     1  0.910786             1   55        158          217          0
# 570     1  0.846040             1   56        128          223          0
# 573     1  0.880447             1   72        160          123          1
# 576     1  0.923235             1   62        139          170          0
# 577     1  0.906544             1   67        146          369          0
# 592     1  0.894600             1   61        190          287          1
# 618     1  0.907425             0   64        128          263          0
# 620     0  0.391097             0   65        120          177          0
# 625     1  0.765471             0   59        135          234          0
# 637     1  0.741610             0   43        115          303          0
# 649     1  0.906542             1   50        144          200          0
# 654     0  0.353788             0   48        122          222          0
# 664     1  0.610615             1   65        150          225          0
# 665     1  0.896830             1   42        136          315          0
# 692     0  0.069249             0   39         94          199          0
# 697     1  0.639339             1   58        150          270          0
# 699     1  0.907610             0   57        110          201          0
# 704     1  0.783008             1   50        150          243          0
# 709     0  0.365119             1   52        125          212          0
# 722     1  0.593142             1   60        150          258          0
# 724     0  0.279485             0   45        112          160          0
# 727     0  0.190863             1   60        158          305          0
# 742     0  0.317431             0   52        136          196          0
# 750     0  0.395324             0   46        142          177          0
# 782     1  0.516589             0   53        130          197          1
# 783     1  0.781187             0   45        138          236          0
# 790     1  0.726832             1   62        138          294          1
# 796     1  0.780742             1   56        134          409          0
# 842     1  0.867836             1   43        132          341          1
# 850     0  0.464461             1   62        160          164          0
# 855     1  0.859573             1   68        180          274          1
# 868     0  0.178747             0   51        110          175          0
# 872     1  0.897560             1   55        132          353          0
# 898     0  0.130372             0   35        122          192          0
# 905     1  0.558975             1   67        152          212          0
# 906     0  0.060577             0   55        132          342          0
# 911     1  0.876900             1   59        164          176          1
#
#      MaxHR  Oldpeak  Sex_F  Sex_M  ChestPainType_ASY  ChestPainType_ATA  \
# 4      122      0.0  False   True              False              False
# 6      170      0.0   True  False              False               True
# 19     160      3.0  False   True              False               True
# 27     118      0.0  False   True              False               True
# 33     130      2.0  False   True               True              False
# 36      87      1.5  False   True               True              False
# 42     168      0.0  False   True              False               True
# 47     170      0.0  False   True              False               True
# 53     150      0.0   True  False              False               True
# 71     135      0.0  False   True              False               True
# 78     138      0.0  False   True              False               True
# 86     112      2.0  False   True               True              False
# 92     148      0.0   True  False              False               True
# 117    130      1.5   True  False               True              False
# 128    140      0.0   True  False              False               True
# 168    100      0.0  False   True               True              False
# 171    188      0.0  False   True              False              False
# 181    150      0.0  False   True              False               True
# 183    140      1.0  False   True               True              False
# 188    110      1.0   True  False               True              False
# 198    116      0.0  False   True               True              False
# 202    146      0.0  False   True              False              False
# 206    180      0.0  False   True              False               True
# 209    140      0.0  False   True               True              False
# 232    129      0.0   True  False              False               True
# 241    142      2.0  False   True               True              False
# 247    150      2.0  False   True               True              False
# 260    165      0.0  False   True              False               True
# 274    180      0.0   True  False              False               True
# 285    120      0.0   True  False              False              False
# 286    140      0.0  False   True               True              False
# 302    120      1.5  False   True               True              False
# 332    179     -1.1  False   True              False              False
# 345    130      0.0  False   True               True              False
# 365    140      1.0   True  False               True              False
# 373    115      1.0  False   True               True              False
# 374    105      0.0  False   True               True              False
# 381    120      0.5  False   True               True              False
# 408     94      0.0  False   True               True              False
# 425    157      0.5  False   True              False               True
# 428    120      0.5  False   True               True              False
# 441    129      1.0  False   True               True              False
# 470    106      0.0  False   True               True              False
# 476    139      0.1  False   True               True              False
# 490    102      1.0  False   True              False              False
# 491    108      0.0  False   True               True              False
# 500    140      4.0  False   True               True              False
# 512    153     -0.1  False   True              False              False
# 523    117      1.0  False   True               True              False
# 526    113      1.7  False   True               True              False
# 528    127      1.5  False   True              False              False
# 541    120      3.5  False   True              False              False
# 569    110      2.5  False   True               True              False
# 570    119      2.0  False   True               True              False
# 573    130      1.5  False   True               True              False
# 576    120      3.0  False   True               True              False
# 577    110      1.9  False   True               True              False
# 592    150      2.0  False   True               True              False
# 618    105      0.2  False   True               True              False
# 620    140      0.4  False   True               True              False
# 625    161      0.5  False   True               True              False
# 637    181      1.2  False   True               True              False
# 649    126      0.9  False   True               True              False
# 654    186      0.0  False   True               True              False
# 664    114      1.0   True  False               True              False
# 665    125      1.8  False   True               True              False
# 692    179      0.0   True  False              False              False
# 697    111      0.8  False   True               True              False
# 699    126      1.5  False   True               True              False
# 704    128      2.6  False   True               True              False
# 709    168      1.0  False   True               True              False
# 722    157      2.6   True  False               True              False
# 724    138      0.0   True  False              False               True
# 727    161      0.0   True  False               True              False
# 742    169      0.1   True  False              False              False
# 750    160      1.4   True  False              False              False
# 782    152      1.2  False   True              False              False
# 783    152      0.2   True  False               True              False
# 790    106      1.9   True  False               True              False
# 796    150      1.9   True  False               True              False
# 842    136      3.0   True  False               True              False
# 850    145      6.2   True  False               True              False
# 855    150      1.6  False   True              False              False
# 868    123      0.6  False   True              False              False
# 872    132      1.2  False   True               True              False
# 898    174      0.0  False   True              False               True
# 905    150      0.8  False   True              False              False
# 906    166      1.2   True  False              False               True
# 911     90      1.0  False   True               True              False
#
#      ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 4                 True             False           False               True
# 6                False             False           False               True
# 19               False             False           False               True
# 27               False             False           False               True
# 33               False             False           False              False
# 36               False             False           False               True
# 42               False             False           False               True
# 47               False             False           False               True
# 53               False             False           False               True
# 71               False             False           False               True
# 78               False             False           False               True
# 86               False             False           False               True
# 92               False             False           False               True
# 117              False             False           False              False
# 128              False             False           False               True
# 168              False             False           False               True
# 171               True             False           False               True
# 181              False             False           False               True
# 183              False             False           False              False
# 188              False             False           False               True
# 198              False             False           False               True
# 202               True             False           False               True
# 206              False             False            True              False
# 209              False             False           False               True
# 232              False             False           False               True
# 241              False             False           False               True
# 247              False             False           False              False
# 260              False             False           False               True
# 274              False             False           False               True
# 285               True             False           False               True
# 286              False             False           False               True
# 302              False             False           False               True
# 332               True             False           False               True
# 345              False             False           False               True
# 365              False             False           False               True
# 373              False             False           False               True
# 374              False             False           False               True
# 381              False             False           False               True
# 408              False             False           False               True
# 425              False             False           False              False
# 428              False             False           False               True
# 441              False             False           False              False
# 470              False             False           False               True
# 476              False             False            True              False
# 490               True             False           False               True
# 491              False             False           False              False
# 500              False             False           False               True
# 512               True             False           False              False
# 523              False             False           False               True
# 526              False             False            True              False
# 528               True             False           False               True
# 541               True             False            True              False
# 569              False             False           False               True
# 570              False             False           False              False
# 573              False             False            True              False
# 576              False             False           False              False
# 577              False             False           False               True
# 592              False             False            True              False
# 618              False             False           False               True
# 620              False             False           False               True
# 625              False             False           False               True
# 637              False             False           False               True
# 649              False             False            True              False
# 654              False             False            True              False
# 664              False             False            True              False
# 665              False             False           False               True
# 692               True             False           False               True
# 697              False             False            True              False
# 699              False             False           False               True
# 704              False             False            True              False
# 709              False             False           False               True
# 722              False             False            True              False
# 724              False             False           False               True
# 727              False             False            True              False
# 742               True             False            True              False
# 750               True             False            True              False
# 782               True             False            True              False
# 783              False             False            True              False
# 790              False             False           False               True
# 796              False             False            True              False
# 842              False             False            True              False
# 850              False             False            True              False
# 855               True             False            True              False
# 868               True             False           False               True
# 872              False             False           False               True
# 898              False             False           False               True
# 905               True             False            True              False
# 906              False             False           False               True
# 911              False             False            True              False
#
#      RestingECG_ST  ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  \
# 4            False              True             False          False
# 6            False              True             False          False
# 19           False              True             False          False
# 27           False              True             False          False
# 33            True              True             False          False
# 36           False             False              True          False
# 42           False              True             False          False
# 47           False              True             False          False
# 53           False              True             False          False
# 71           False              True             False          False
# 78           False             False              True          False
# 86           False             False              True          False
# 92           False              True             False          False
# 117           True             False              True          False
# 128          False              True             False          False
# 168          False              True             False          False
# 171          False              True             False          False
# 181          False              True             False          False
# 183           True             False              True          False
# 188          False             False              True          False
# 198          False             False              True          False
# 202          False              True             False          False
# 206          False              True             False          False
# 209          False              True             False          False
# 232          False              True             False          False
# 241          False             False              True          False
# 247           True             False              True           True
# 260          False             False              True          False
# 274          False              True             False          False
# 285          False              True             False          False
# 286          False              True             False          False
# 302          False              True             False          False
# 332          False              True             False          False
# 345          False              True             False          False
# 365          False             False              True          False
# 373          False             False              True          False
# 374          False             False              True           True
# 381          False             False              True          False
# 408          False              True             False          False
# 425           True              True             False          False
# 428          False             False              True          False
# 441           True              True             False          False
# 470          False              True             False          False
# 476          False              True             False          False
# 490          False             False              True          False
# 491           True              True             False          False
# 500          False             False              True           True
# 512           True              True             False          False
# 523          False             False              True          False
# 526          False             False              True          False
# 528          False             False              True          False
# 541          False              True             False           True
# 569          False             False              True          False
# 570           True             False              True           True
# 573          False              True             False          False
# 576           True             False              True          False
# 577          False             False              True          False
# 592          False             False              True           True
# 618          False             False              True          False
# 620          False              True             False          False
# 625          False              True             False          False
# 637          False              True             False          False
# 649          False             False              True          False
# 654          False              True             False          False
# 664          False              True             False          False
# 665          False             False              True          False
# 692          False              True             False          False
# 697          False             False              True          False
# 699          False             False              True          False
# 704          False              True             False          False
# 709          False              True             False          False
# 722          False              True             False          False
# 724          False              True             False          False
# 727          False              True             False          False
# 742          False              True             False          False
# 750          False             False              True           True
# 782          False              True             False           True
# 783          False             False              True          False
# 790          False              True             False          False
# 796          False             False              True          False
# 842          False             False              True          False
# 850          False              True             False           True
# 855          False             False              True          False
# 868          False              True             False          False
# 872          False             False              True          False
# 898          False              True             False          False
# 905          False              True             False          False
# 906          False              True             False          False
# 911          False              True             False          False
#
#      ST_Slope_Flat  ST_Slope_Up
# 4            False         True
# 6            False         True
# 19            True        False
# 27           False         True
# 33            True        False
# 36            True        False
# 42           False         True
# 47           False         True
# 53           False         True
# 71           False         True
# 78           False         True
# 86            True        False
# 92           False         True
# 117           True        False
# 128          False         True
# 168          False         True
# 171          False         True
# 181          False         True
# 183           True        False
# 188           True        False
# 198           True        False
# 202          False         True
# 206          False         True
# 209           True        False
# 232          False         True
# 241           True        False
# 247          False        False
# 260          False         True
# 274          False         True
# 285          False         True
# 286          False         True
# 302          False         True
# 332          False         True
# 345           True        False
# 365           True        False
# 373           True        False
# 374          False        False
# 381           True        False
# 408           True        False
# 425           True        False
# 428           True        False
# 441           True        False
# 470           True        False
# 476          False         True
# 490           True        False
# 491           True        False
# 500          False        False
# 512          False         True
# 523           True        False
# 526           True        False
# 528           True        False
# 541          False        False
# 569           True        False
# 570          False        False
# 573           True        False
# 576           True        False
# 577           True        False
# 592          False        False
# 618           True        False
# 620          False         True
# 625           True        False
# 637           True        False
# 649           True        False
# 654          False         True
# 664           True        False
# 665           True        False
# 692          False         True
# 697          False         True
# 699           True        False
# 704           True        False
# 709          False         True
# 722           True        False
# 724           True        False
# 727          False         True
# 742           True        False
# 750          False        False
# 782          False        False
# 783           True        False
# 790           True        False
# 796           True        False
# 842           True        False
# 850          False        False
# 855           True        False
# 868          False         True
# 872           True        False
# 898          False         True
# 905           True        False
# 906          False         True
# 911           True        False
